# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
flow201902 = pd.read_csv("4개지역_FLOW_AGE_201902.csv", sep ="|")
flow201903 = pd.read_csv("4개지역_FLOW_AGE_201903.csv", sep ="|")
flow201904 = pd.read_csv("4개지역_FLOW_AGE_201904.csv", sep ="|")
flow201905 = pd.read_csv("4개지역_FLOW_AGE_201905.csv", sep ="|")
flow202002 = pd.read_csv("4개지역_FLOW_AGE_202002.csv", sep ="|")
flow202003 = pd.read_csv("4개지역_FLOW_AGE_202003.csv", sep ="|")
flow202004 = pd.read_csv("4개지역_FLOW_AGE_202004.csv", sep ="|")
flow202005 = pd.read_csv("4개지역_FLOW_AGE_202005.csv", sep ="|")

# %%
flow201902.head()
# Out:
#    STD_YM   STD_YMD    HDONG_CD HDONG_NM  MAN_FLOW_POP_CNT_0004  \
# 0  201902  20190201  1114052000      소공동                  16.64
# 1  201902  20190202  1114052000      소공동                   3.14
# 2  201902  20190203  1114052000      소공동                   1.38
# 3  201902  20190204  1114052000      소공동                   0.08
# 4  201902  20190205  1114052000      소공동                   0.00
#
#    MAN_FLOW_POP_CNT_0509  MAN_FLOW_POP_CNT_1014  MAN_FLOW_POP_CNT_1519  \
# 0                 116.18                 419.70                1553.57
# 1                 141.07                 763.30                1405.29
# 2                 120.39                 698.23                1117.17
# 3                 141.61                 772.41                1248.85
# 4                 254.70                1394.92                2190.69
#
#    MAN_FLOW_POP_CNT_2024  MAN_FLOW_POP_CNT_2529  ...  WMAN_FLOW_POP_CNT_2529  \
# ...

# %%
flow201902.tail()
# Out:
#       STD_YM   STD_YMD    HDONG_CD HDONG_NM  MAN_FLOW_POP_CNT_0004  \
# 1927  201902  20190224  2726069000     고산3동                   0.05
# 1928  201902  20190225  2726069000     고산3동                   0.05
# 1929  201902  20190226  2726069000     고산3동                   0.03
# 1930  201902  20190227  2726069000     고산3동                   0.08
# 1931  201902  20190228  2726069000     고산3동                   0.19
#
#       MAN_FLOW_POP_CNT_0509  MAN_FLOW_POP_CNT_1014  MAN_FLOW_POP_CNT_1519  \
# 1927                 146.86                 677.67                1084.16
# 1928                 187.83                 534.66                1024.18
# 1929                 146.97                 494.97                 925.04
# 1930                 164.30                 555.82                1027.75
# 1931                 173.51                 508.44                1107.87
#
#       MAN_FLOW_POP_CNT_2024  MAN_FLOW_POP_CNT_2529  ...  \
# 1927                1545.11                1952.14  ...
# ...

# %%
flow201902_MAN = flow201902.groupby("STD_YM")["MAN_FLOW_POP_CNT_0509", "MAN_FLOW_POP_CNT_1014","MAN_FLOW_POP_CNT_1519"
                            ,"MAN_FLOW_POP_CNT_2529","MAN_FLOW_POP_CNT_3539","MAN_FLOW_POP_CNT_4549",
                            "MAN_FLOW_POP_CNT_5559","MAN_FLOW_POP_CNT_6569","MAN_FLOW_POP_CNT_70U"].sum()

# %%
flow201903_MAN = flow201903.groupby("STD_YM")["MAN_FLOW_POP_CNT_0509", "MAN_FLOW_POP_CNT_1014","MAN_FLOW_POP_CNT_1519"
                            ,"MAN_FLOW_POP_CNT_2529","MAN_FLOW_POP_CNT_3539","MAN_FLOW_POP_CNT_4549",
                            "MAN_FLOW_POP_CNT_5559","MAN_FLOW_POP_CNT_6569","MAN_FLOW_POP_CNT_70U"].sum()

# %%
flow201904_MAN = flow201904.groupby("STD_YM")["MAN_FLOW_POP_CNT_0509", "MAN_FLOW_POP_CNT_1014","MAN_FLOW_POP_CNT_1519"
                            ,"MAN_FLOW_POP_CNT_2529","MAN_FLOW_POP_CNT_3539","MAN_FLOW_POP_CNT_4549",
                            "MAN_FLOW_POP_CNT_5559","MAN_FLOW_POP_CNT_6569","MAN_FLOW_POP_CNT_70U"].sum()

# %%
flow201905_MAN = flow201905.groupby("STD_YM")["MAN_FLOW_POP_CNT_0509", "MAN_FLOW_POP_CNT_1014","MAN_FLOW_POP_CNT_1519"
                            ,"MAN_FLOW_POP_CNT_2529","MAN_FLOW_POP_CNT_3539","MAN_FLOW_POP_CNT_4549",
                            "MAN_FLOW_POP_CNT_5559","MAN_FLOW_POP_CNT_6569","MAN_FLOW_POP_CNT_70U"].sum()

# %%
flow201902_WOMAN = flow201902.groupby("STD_YM")["WMAN_FLOW_POP_CNT_0509", "WMAN_FLOW_POP_CNT_1014","WMAN_FLOW_POP_CNT_1519"
                            ,"WMAN_FLOW_POP_CNT_2529","WMAN_FLOW_POP_CNT_3539","WMAN_FLOW_POP_CNT_4549",
                            "WMAN_FLOW_POP_CNT_5559","WMAN_FLOW_POP_CNT_6569","WMAN_FLOW_POP_CNT_70U"].sum()

# %%
flow201903_WOMAN = flow201903.groupby("STD_YM")["WMAN_FLOW_POP_CNT_0509", "WMAN_FLOW_POP_CNT_1014","WMAN_FLOW_POP_CNT_1519"
                            ,"WMAN_FLOW_POP_CNT_2529","WMAN_FLOW_POP_CNT_3539","WMAN_FLOW_POP_CNT_4549",
                            "WMAN_FLOW_POP_CNT_5559","WMAN_FLOW_POP_CNT_6569","WMAN_FLOW_POP_CNT_70U"].sum()

# %%
flow201904_WOMAN = flow201904.groupby("STD_YM")["WMAN_FLOW_POP_CNT_0509", "WMAN_FLOW_POP_CNT_1014","WMAN_FLOW_POP_CNT_1519"
                            ,"WMAN_FLOW_POP_CNT_2529","WMAN_FLOW_POP_CNT_3539","WMAN_FLOW_POP_CNT_4549",
                            "WMAN_FLOW_POP_CNT_5559","WMAN_FLOW_POP_CNT_6569","WMAN_FLOW_POP_CNT_70U"].sum()

# %%
flow201905_WOMAN = flow201905.groupby("STD_YM")["WMAN_FLOW_POP_CNT_0509", "WMAN_FLOW_POP_CNT_1014","WMAN_FLOW_POP_CNT_1519"
                            ,"WMAN_FLOW_POP_CNT_2529","WMAN_FLOW_POP_CNT_3539","WMAN_FLOW_POP_CNT_4549",
                            "WMAN_FLOW_POP_CNT_5559","WMAN_FLOW_POP_CNT_6569","WMAN_FLOW_POP_CNT_70U"].sum()

# %%
flow202002_MAN = flow202002.groupby("STD_YM")["MAN_FLOW_POP_CNT_0509", "MAN_FLOW_POP_CNT_1014","MAN_FLOW_POP_CNT_1519"
                            ,"MAN_FLOW_POP_CNT_2529","MAN_FLOW_POP_CNT_3539","MAN_FLOW_POP_CNT_4549",
                            "MAN_FLOW_POP_CNT_5559","MAN_FLOW_POP_CNT_6569","MAN_FLOW_POP_CNT_70U"].sum()

# %%
flow202003_MAN = flow202003.groupby("STD_YM")["MAN_FLOW_POP_CNT_0509", "MAN_FLOW_POP_CNT_1014","MAN_FLOW_POP_CNT_1519"
                            ,"MAN_FLOW_POP_CNT_2529","MAN_FLOW_POP_CNT_3539","MAN_FLOW_POP_CNT_4549",
                            "MAN_FLOW_POP_CNT_5559","MAN_FLOW_POP_CNT_6569","MAN_FLOW_POP_CNT_70U"].sum()

# %%
flow202004_MAN = flow202004.groupby("STD_YM")["MAN_FLOW_POP_CNT_0509", "MAN_FLOW_POP_CNT_1014","MAN_FLOW_POP_CNT_1519"
                            ,"MAN_FLOW_POP_CNT_2529","MAN_FLOW_POP_CNT_3539","MAN_FLOW_POP_CNT_4549",
                            "MAN_FLOW_POP_CNT_5559","MAN_FLOW_POP_CNT_6569","MAN_FLOW_POP_CNT_70U"].sum()

# %%
flow202005_MAN = flow202005.groupby("STD_YM")["MAN_FLOW_POP_CNT_0509", "MAN_FLOW_POP_CNT_1014","MAN_FLOW_POP_CNT_1519"
                            ,"MAN_FLOW_POP_CNT_2529","MAN_FLOW_POP_CNT_3539","MAN_FLOW_POP_CNT_4549",
                            "MAN_FLOW_POP_CNT_5559","MAN_FLOW_POP_CNT_6569","MAN_FLOW_POP_CNT_70U"].sum()

# %%
flow202002_WOMAN = flow202002.groupby("STD_YM")["WMAN_FLOW_POP_CNT_0509", "WMAN_FLOW_POP_CNT_1014","WMAN_FLOW_POP_CNT_1519"
                            ,"WMAN_FLOW_POP_CNT_2529","WMAN_FLOW_POP_CNT_3539","WMAN_FLOW_POP_CNT_4549",
                            "WMAN_FLOW_POP_CNT_5559","WMAN_FLOW_POP_CNT_6569","WMAN_FLOW_POP_CNT_70U"].sum()

# %%
flow202003_WOMAN = flow202003.groupby("STD_YM")["WMAN_FLOW_POP_CNT_0509", "WMAN_FLOW_POP_CNT_1014","WMAN_FLOW_POP_CNT_1519"
                            ,"WMAN_FLOW_POP_CNT_2529","WMAN_FLOW_POP_CNT_3539","WMAN_FLOW_POP_CNT_4549",
                            "WMAN_FLOW_POP_CNT_5559","WMAN_FLOW_POP_CNT_6569","WMAN_FLOW_POP_CNT_70U"].sum()

# %%
flow202004_WOMAN = flow202004.groupby("STD_YM")["WMAN_FLOW_POP_CNT_0509", "WMAN_FLOW_POP_CNT_1014","WMAN_FLOW_POP_CNT_1519"
                            ,"WMAN_FLOW_POP_CNT_2529","WMAN_FLOW_POP_CNT_3539","WMAN_FLOW_POP_CNT_4549",
                            "WMAN_FLOW_POP_CNT_5559","WMAN_FLOW_POP_CNT_6569","WMAN_FLOW_POP_CNT_70U"].sum()

# %%
flow202005_WOMAN = flow202005.groupby("STD_YM")["WMAN_FLOW_POP_CNT_0509", "WMAN_FLOW_POP_CNT_1014","WMAN_FLOW_POP_CNT_1519"
                            ,"WMAN_FLOW_POP_CNT_2529","WMAN_FLOW_POP_CNT_3539","WMAN_FLOW_POP_CNT_4549",
                            "WMAN_FLOW_POP_CNT_5559","WMAN_FLOW_POP_CNT_6569","WMAN_FLOW_POP_CNT_70U"].sum()

# %%
man_2019 = pd.concat([flow201902_MAN, flow201903_MAN, flow201904_MAN, flow201905_MAN])
woman_2019 = pd.concat([flow201902_WOMAN, flow201903_WOMAN, flow201904_WOMAN, flow201905_WOMAN])
man_2020 = pd.concat([flow202002_MAN, flow202003_MAN, flow202004_MAN, flow202005_MAN])
woman_2020 = pd.concat([flow202002_WOMAN, flow202003_WOMAN, flow202004_WOMAN, flow202005_WOMAN])

# %%
man = pd.concat([man_2019, man_2020])
woman = pd.concat([woman_2019, woman_2020])

# %%
# 월별 코로나 확진자 수
corona = [0, 0, 0, 0, 3736, 9887, 10774, 11503]

# %%
man['corona'] = corona
woman['corona'] = corona

# %%
man = man.reset_index()
woman = woman.reset_index()

# %% [markdown]
# # 시간에 따른 남자 연령대별 유동인구

# %%
man.head()
# Out:
#    STD_YM  MAN_FLOW_POP_CNT_0509  MAN_FLOW_POP_CNT_1014  \
# 0  201902              232546.34             1134165.89
# 1  201903              286187.30             1175055.60
# 2  201904              282272.23             1331063.73
# 3  201905              347215.30             1574839.03
# 4  202002              155857.42              922387.41
#
#    MAN_FLOW_POP_CNT_1519  MAN_FLOW_POP_CNT_2529  MAN_FLOW_POP_CNT_3539  \
# 0             2708266.18             6890266.59             9125174.41
# 1             3623906.63             7792206.10            10355000.58
# 2             3557288.55             6933540.50             9382103.87
# 3             4024116.69             7381162.63             9658166.28
# 4             1958302.10             5545092.66             7366179.59
#
#    MAN_FLOW_POP_CNT_4549  MAN_FLOW_POP_CNT_5559  MAN_FLOW_POP_CNT_6569  \
# 0            10807517.72             9454608.89             6028797.46
# ...

# %%
# 남자의 모든 연령대별 유동인구, 4이후로 2020년
man.plot(kind="line")

# %% [markdown]
# - 1집단 : 아마 생산연령(출퇴근)이기 때문에 40대 > 50대 > 30대 순으로 유동인구가 많은 것 같다
# - 2집단 : 그 다음 20대 > 70대이상 > 60대 순으로 이루어짐

# %%
# 여자의 모든 연령대별 유동인구, 4이후로 2020년
woman.plot()

# %% [markdown]
# - 1집단 : 여기도 생산연령(출퇴근)이기 때문에 40대 > 30대 > 50대 > 20대 순으로 유동인구가 많은 것 같다
# - 2집단 : 그 다음 70대 이상 > 60대 > 10대 순으로 이루어짐
#
#
# - 여자가 남자보다 유동인구 증감폭이 더 큼 : 코로나에 더 민감하거나, 남자가 회사 다니는 비율이 많아서 그런 걸수도??라고 해석할 수 있음

# %%
# 남자 40대 월별 유동인구
plt.subplot(2,1,1)
plt.plot(man["MAN_FLOW_POP_CNT_4549"])
plt.subplot(2,1,2)
plt.plot(man["corona"])

# %%
# 여자 40대 월별 유동인구
plt.subplot(2,1,1)
plt.plot(woman["WMAN_FLOW_POP_CNT_4549"])
plt.subplot(2,1,2)
plt.plot(woman["corona"])

# %%
# 남자 20대 월별 유동인구
plt.subplot(2,1,1)
plt.plot(woman["WMAN_FLOW_POP_CNT_2529"])
plt.subplot(2,1,2)
plt.plot(woman["corona"])

# %%
# 여자 20대 월별 유동인구
plt.subplot(2,1,1)
plt.plot(man["MAN_FLOW_POP_CNT_2529"])
plt.subplot(2,1,2)
plt.plot(man["corona"])

# %%
# 남자 20대 월별 유동인구
plt.subplot(2,1,1)
plt.plot(man["MAN_FLOW_POP_CNT_6569"])
plt.subplot(2,1,2)
plt.plot(man["corona"])

# %%
# 여자 20대 월별 유동인구
plt.subplot(2,1,1)
plt.plot(woman["WMAN_FLOW_POP_CNT_2529"])
plt.subplot(2,1,2)
plt.plot(woman["corona"])

# %%
# 여자 60대 월별 유동인구
plt.subplot(2,1,1)
plt.plot(woman["WMAN_FLOW_POP_CNT_6569"])
plt.subplot(2,1,2)
plt.plot(woman["corona"])

# %%
man.to_csv("man_flow.csv", mode='a')
woman.to_csv("woman_flow.csv", mode='a')

# %% [markdown]
# ## 그냥 내 생각
# - 코로나 이후로 유동인구가 급감소함
# - 그러나 코로나가 잠잠해짐에 따라, 다시 유동인구가 급증가
# - 2개월동안 확줄고, 2개월동안 급증가(코로나에 대한 감각이 무뎌짐?)
# - 남자는 여자에 비해 유동인구가 작은폭으로 증감함
